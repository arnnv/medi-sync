# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
# Define the function to load the dataset
def load_path(path, part):
    dataset = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for body in os.listdir(folder_path):
                if body == part:
                    body_part = body
                    body_path = os.path.join(folder_path, body)
                    for patient_id in os.listdir(body_path):
                        patient_path = os.path.join(body_path, patient_id)
                        for lab in os.listdir(patient_path):
                            label = 'fractured' if lab.split('_')[-1] == 'positive' else 'normal'
                            lab_path = os.path.join(patient_path, lab)
                            for img in os.listdir(lab_path):
                                img_path = os.path.join(lab_path, img)
                                dataset.append({
                                    'body_part': body_part,
                                    'patient_id': patient_id,
                                    'label': label,
                                    'image_path': img_path
                                })
    return dataset

# %%
def prepare_data(part):
    image_dir = './dataset/'
    data = load_path(image_dir, part)
    labels = [row['label'] for row in data]
    filepaths = [row['image_path'] for row in data]

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    train_df, test_df = train_test_split(images, train_size=0.9, shuffle=True, random_state=1)

    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        horizontal_flip=True,
        preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
        validation_split=0.2
    )

    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.resnet50.preprocess_input
    )

    train_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=64,
        shuffle=True,
        seed=42,
        subset='training'
    )

    val_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=64,
        shuffle=True,
        seed=42,
        subset='validation'
    )

    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )

    return train_images, val_images, test_images

# %%
def create_model():
    pretrained_model = tf.keras.applications.ResNet50(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg'
    )

    pretrained_model.trainable = False

    inputs = pretrained_model.input
    x = pretrained_model.output
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)  # Add dropout for regularization
    x = tf.keras.layers.BatchNormalization()(x)  # Add batch normalization
    x = tf.keras.layers.Dense(50, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.2)(x)  # Add dropout for regularization
    outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
def train_model(part, train_images, val_images, test_images):
    model = create_model()

    print("-------Training " + part + "-------")

    # Define callbacks
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(os.getcwd(), f"weights/ResNet50_{part}_frac.h5"),
        monitor='val_loss',
        save_best_only=True
    )

    reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=2,
        min_lr=0.0001
    )

    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=3, restore_best_weights=True
    )

    # Train the model
    history = model.fit(
        train_images,
        validation_data=val_images,
        epochs=25,
        callbacks=[checkpoint_callback, reduce_lr_callback, early_stopping_callback]
    )

    # Evaluate the model
    results = model.evaluate(test_images, verbose=0)
    print(part + " Results:")
    print(results)
    print(f"Test Accuracy: {np.round(results[1] * 100, 2)}%")

    # Plot accuracy and loss
    os.makedirs(f"./plots/FractureDetection/{part}", exist_ok=True)

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.savefig(f"./plots/FractureDetection/{part}/_Accuracy.jpeg")
    plt.clf()

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.savefig(f"./plots/FractureDetection/{part}/_Loss.jpeg")
    plt.clf()

# %%
categories_parts = ["Elbow", "Hand", "Shoulder"]

for part in categories_parts:
    train_images, val_images, test_images = prepare_data(part)
    train_model(part, train_images, val_images, test_images)
# Out:
# Found 3885 validated image filenames belonging to 2 classes.
# Found 971 validated image filenames belonging to 2 classes.
# Found 540 validated image filenames belonging to 2 classes.
# -------Training Elbow-------
# Epoch 1/25
# 61/61 [==============================] - 35s 261ms/step - loss: 0.7899 - accuracy: 0.5709 - val_loss: 0.6155 - val_accuracy: 0.6643 - lr: 1.0000e-04
# Epoch 2/25
# 61/61 [==============================] - 12s 196ms/step - loss: 0.6593 - accuracy: 0.6541 - val_loss: 0.5708 - val_accuracy: 0.7291 - lr: 1.0000e-04
# Epoch 3/25
# 61/61 [==============================] - 12s 197ms/step - loss: 0.6089 - accuracy: 0.6986 - val_loss: 0.5466 - val_accuracy: 0.7559 - lr: 1.0000e-04
# Epoch 4/25
# 61/61 [==============================] - 12s 202ms/step - loss: 0.5859 - accuracy: 0.6983 - val_loss: 0.5286 - val_accuracy: 0.7621 - lr: 1.0000e-04
# Epoch 5/25
# 61/61 [==============================] - 12s 193ms/step - loss: 0.5525 - accuracy: 0.7351 - val_loss: 0.5262 - val_accuracy: 0.7621 - lr: 1.0000e-04
# Epoch 6/25
# 61/61 [==============================] - 12s 196ms/step - loss: 0.5431 - accuracy: 0.7351 - val_loss: 0.5156 - val_accuracy: 0.7683 - lr: 1.0000e-04
# Epoch 7/25
# 61/61 [==============================] - 12s 194ms/step - loss: 0.5208 - accuracy: 0.7557 - val_loss: 0.5111 - val_accuracy: 0.7508 - lr: 1.0000e-04
# Epoch 8/25
# 61/61 [==============================] - 11s 186ms/step - loss: 0.4942 - accuracy: 0.7611 - val_loss: 0.5130 - val_accuracy: 0.7683 - lr: 1.0000e-04
# Epoch 9/25
# 61/61 [==============================] - 12s 195ms/step - loss: 0.4919 - accuracy: 0.7642 - val_loss: 0.5023 - val_accuracy: 0.7590 - lr: 1.0000e-04
# Epoch 10/25
# 61/61 [==============================] - 12s 195ms/step - loss: 0.4699 - accuracy: 0.7732 - val_loss: 0.4945 - val_accuracy: 0.7703 - lr: 1.0000e-04
# Epoch 11/25
# 61/61 [==============================] - 12s 196ms/step - loss: 0.4726 - accuracy: 0.7761 - val_loss: 0.4920 - val_accuracy: 0.7806 - lr: 1.0000e-04
# Epoch 12/25
# 61/61 [==============================] - 12s 195ms/step - loss: 0.4565 - accuracy: 0.7892 - val_loss: 0.4902 - val_accuracy: 0.7724 - lr: 1.0000e-04
# Epoch 13/25
# 61/61 [==============================] - 12s 194ms/step - loss: 0.4494 - accuracy: 0.7861 - val_loss: 0.4860 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 14/25
# 61/61 [==============================] - 11s 186ms/step - loss: 0.4330 - accuracy: 0.8044 - val_loss: 0.4924 - val_accuracy: 0.7734 - lr: 1.0000e-04
# Epoch 15/25
# 61/61 [==============================] - 11s 186ms/step - loss: 0.4267 - accuracy: 0.8039 - val_loss: 0.4922 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 16/25
# 61/61 [==============================] - 12s 202ms/step - loss: 0.4280 - accuracy: 0.8010 - val_loss: 0.4784 - val_accuracy: 0.7899 - lr: 1.0000e-04
# Epoch 17/25
# 61/61 [==============================] - 13s 204ms/step - loss: 0.4029 - accuracy: 0.8193 - val_loss: 0.5086 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Epoch 18/25
# 61/61 [==============================] - 12s 193ms/step - loss: 0.3899 - accuracy: 0.8301 - val_loss: 0.4954 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 19/25
# 61/61 [==============================] - 12s 195ms/step - loss: 0.3966 - accuracy: 0.8260 - val_loss: 0.4927 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Elbow Results:
# [0.42239177227020264, 0.8259259462356567]
# Test Accuracy: 82.59%
# Found 4322 validated image filenames belonging to 2 classes.
# Found 1080 validated image filenames belonging to 2 classes.
# Found 601 validated image filenames belonging to 2 classes.
# -------Training Hand-------
# Epoch 1/25
# 68/68 [==============================] - 19s 249ms/step - loss: 0.8536 - accuracy: 0.5127 - val_loss: 0.7454 - val_accuracy: 0.4898 - lr: 1.0000e-04
# Epoch 2/25
# 68/68 [==============================] - 13s 196ms/step - loss: 0.6691 - accuracy: 0.6340 - val_loss: 0.5459 - val_accuracy: 0.7370 - lr: 1.0000e-04
# Epoch 3/25
# 68/68 [==============================] - 14s 200ms/step - loss: 0.6111 - accuracy: 0.6872 - val_loss: 0.5321 - val_accuracy: 0.7639 - lr: 1.0000e-04
# Epoch 4/25
# 68/68 [==============================] - 14s 197ms/step - loss: 0.5895 - accuracy: 0.7131 - val_loss: 0.5181 - val_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 5/25
# 68/68 [==============================] - 14s 205ms/step - loss: 0.5670 - accuracy: 0.7298 - val_loss: 0.5139 - val_accuracy: 0.7759 - lr: 1.0000e-04
# Epoch 6/25
# 68/68 [==============================] - 13s 190ms/step - loss: 0.5473 - accuracy: 0.7392 - val_loss: 0.5214 - val_accuracy: 0.7611 - lr: 1.0000e-04
# Epoch 7/25
# 68/68 [==============================] - 13s 194ms/step - loss: 0.5384 - accuracy: 0.7450 - val_loss: 0.5060 - val_accuracy: 0.7694 - lr: 1.0000e-04
# Epoch 8/25
# 68/68 [==============================] - 13s 196ms/step - loss: 0.5329 - accuracy: 0.7564 - val_loss: 0.4981 - val_accuracy: 0.7713 - lr: 1.0000e-04
# Epoch 9/25
# 68/68 [==============================] - 13s 189ms/step - loss: 0.5180 - accuracy: 0.7584 - val_loss: 0.5034 - val_accuracy: 0.7769 - lr: 1.0000e-04
# Epoch 10/25
# 68/68 [==============================] - 13s 190ms/step - loss: 0.5086 - accuracy: 0.7635 - val_loss: 0.5055 - val_accuracy: 0.7843 - lr: 1.0000e-04
# Epoch 11/25
# 68/68 [==============================] - 13s 197ms/step - loss: 0.4778 - accuracy: 0.7839 - val_loss: 0.4861 - val_accuracy: 0.7870 - lr: 1.0000e-04
# Epoch 12/25
# 68/68 [==============================] - 13s 193ms/step - loss: 0.4747 - accuracy: 0.7846 - val_loss: 0.5021 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 13/25
# 68/68 [==============================] - 13s 195ms/step - loss: 0.4835 - accuracy: 0.7839 - val_loss: 0.4780 - val_accuracy: 0.7861 - lr: 1.0000e-04
# Epoch 14/25
# 68/68 [==============================] - 13s 189ms/step - loss: 0.4732 - accuracy: 0.7844 - val_loss: 0.4843 - val_accuracy: 0.7852 - lr: 1.0000e-04
# Epoch 15/25
# 68/68 [==============================] - 13s 189ms/step - loss: 0.4605 - accuracy: 0.7927 - val_loss: 0.4796 - val_accuracy: 0.7917 - lr: 1.0000e-04
# Epoch 16/25
# 68/68 [==============================] - 13s 189ms/step - loss: 0.4508 - accuracy: 0.7992 - val_loss: 0.4813 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Hand Results:
# [0.5307796001434326, 0.7703827023506165]
# Test Accuracy: 77.04%
# Found 6434 validated image filenames belonging to 2 classes.
# Found 1608 validated image filenames belonging to 2 classes.
# Found 894 validated image filenames belonging to 2 classes.
# -------Training Shoulder-------
# Epoch 1/25
# 101/101 [==============================] - 28s 254ms/step - loss: 0.8273 - accuracy: 0.5699 - val_loss: 0.6232 - val_accuracy: 0.6374 - lr: 1.0000e-04
# Epoch 2/25
# 101/101 [==============================] - 21s 204ms/step - loss: 0.6738 - accuracy: 0.6526 - val_loss: 0.5805 - val_accuracy: 0.7015 - lr: 1.0000e-04
# Epoch 3/25
# 101/101 [==============================] - 21s 204ms/step - loss: 0.6422 - accuracy: 0.6646 - val_loss: 0.5759 - val_accuracy: 0.7040 - lr: 1.0000e-04
# Epoch 4/25
# 101/101 [==============================] - 21s 203ms/step - loss: 0.6180 - accuracy: 0.6815 - val_loss: 0.5651 - val_accuracy: 0.7021 - lr: 1.0000e-04
# Epoch 5/25
# 101/101 [==============================] - 21s 207ms/step - loss: 0.5911 - accuracy: 0.7002 - val_loss: 0.5486 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 6/25
# 101/101 [==============================] - 22s 217ms/step - loss: 0.5677 - accuracy: 0.7210 - val_loss: 0.5545 - val_accuracy: 0.7214 - lr: 1.0000e-04
# Epoch 7/25
# 101/101 [==============================] - 24s 232ms/step - loss: 0.5725 - accuracy: 0.7165 - val_loss: 0.5417 - val_accuracy: 0.7345 - lr: 1.0000e-04
# Epoch 8/25
# 101/101 [==============================] - 61s 605ms/step - loss: 0.5444 - accuracy: 0.7283 - val_loss: 0.5431 - val_accuracy: 0.7295 - lr: 1.0000e-04
# Epoch 9/25
# 101/101 [==============================] - 41s 397ms/step - loss: 0.5374 - accuracy: 0.7334 - val_loss: 0.5405 - val_accuracy: 0.7376 - lr: 1.0000e-04
# Epoch 10/25
# 101/101 [==============================] - 24s 239ms/step - loss: 0.5181 - accuracy: 0.7440 - val_loss: 0.5413 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 11/25
# 101/101 [==============================] - 23s 227ms/step - loss: 0.5215 - accuracy: 0.7409 - val_loss: 0.5473 - val_accuracy: 0.7363 - lr: 1.0000e-04
# Epoch 12/25
# 101/101 [==============================] - 27s 271ms/step - loss: 0.5059 - accuracy: 0.7513 - val_loss: 0.5364 - val_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 13/25
# 101/101 [==============================] - 25s 245ms/step - loss: 0.4968 - accuracy: 0.7519 - val_loss: 0.5371 - val_accuracy: 0.7394 - lr: 1.0000e-04
# Epoch 14/25
# 101/101 [==============================] - 23s 230ms/step - loss: 0.4861 - accuracy: 0.7680 - val_loss: 0.5336 - val_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 15/25
# 101/101 [==============================] - 21s 210ms/step - loss: 0.4908 - accuracy: 0.7645 - val_loss: 0.5345 - val_accuracy: 0.7519 - lr: 1.0000e-04
# Epoch 16/25
# 101/101 [==============================] - 22s 218ms/step - loss: 0.4748 - accuracy: 0.7776 - val_loss: 0.5316 - val_accuracy: 0.7351 - lr: 1.0000e-04
# Epoch 17/25
# 101/101 [==============================] - 23s 226ms/step - loss: 0.4618 - accuracy: 0.7819 - val_loss: 0.5229 - val_accuracy: 0.7463 - lr: 1.0000e-04
# Epoch 18/25
# 101/101 [==============================] - 22s 213ms/step - loss: 0.4588 - accuracy: 0.7866 - val_loss: 0.5429 - val_accuracy: 0.7425 - lr: 1.0000e-04
# Epoch 19/25
# 101/101 [==============================] - 22s 214ms/step - loss: 0.4553 - accuracy: 0.7864 - val_loss: 0.5321 - val_accuracy: 0.7475 - lr: 1.0000e-04
# Epoch 20/25
# 101/101 [==============================] - 21s 207ms/step - loss: 0.4515 - accuracy: 0.7861 - val_loss: 0.5285 - val_accuracy: 0.7363 - lr: 1.0000e-04
# Shoulder Results:
# [0.5685571432113647, 0.7259507775306702]
# Test Accuracy: 72.6%
